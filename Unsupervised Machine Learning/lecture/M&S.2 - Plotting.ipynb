# %% [markdown]
# # M&S.2 - Plotting
# ## Import Matplotlib and Seaborn

# %%
import numpy as np
import pandas as pd

from numpy.random import randn
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ## Jupyter configuration

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10, 5 # width 10 inches, and height 5 inches
sb.set_style('whitegrid')

# %% [markdown]
# ## MATLAB-like interface.
# ### Creating a line chart from a list object

# %%
x = range(1,10)
y = [1,2,3,4,0.5,4,3,2,1]

plt.plot(x, y)

# %%
plt.scatter(x,y)

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 9 artists>

# %%
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x11b94c7b8>,
# ...
#  [Text(1.087108467116997, 0.16791420643451557, ''),
#   Text(0.8997223112950338, 0.6328505056946091, ''),
#   Text(0.2094302755659061, 1.079879141235902, ''),
#   Text(-0.8486380338760866, 0.6998667640765136, ''),
#   Text(-1.0999999999999925, 1.287367912731616e-07, ''),
#   Text(-0.8486381976917022, -0.6998665654384267, ''),
#   Text(0.20943002280194498, -1.079879190256566, ''),
#   Text(0.8997221631656577, -0.6328507162897974, ''),
#   Text(1.0871084278138106, -0.16791446089061257, '')])

# %%
plt.pie(y)
plt.show()

# %% [markdown]
# ## Make plots of DataFrame using Matplotlib/Pylab
# ### Loading dataFrame

# %%
cars = pd.read_csv('../samples/mtcars.csv')
cars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# ### Plotting.

# %%
mpg = cars['mpg']
mpg.plot() #alias of pandas.plotting._core.FramePlotMethods

# %%
df = cars[['cyl', 'wt', 'mpg']]
df.plot()

# %% [markdown]
# ## Matplotlib OO interface
# We use an instance of axes.Axes in order to render visualizations on an instance of figure.Figure.

# %% [markdown]
# ### The Figure Object

# %%
fig = plt.figure()
fig.suptitle("Empty figure")
plt.show(block=False)

# %% [markdown]
# ### The Axes Object
# One or more axes objects are required to get us started with plotting.

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(x,y)
plt.show()

# %% [markdown]
# #### add_subplot(num_rows, num_cols, subplot_location)
#
# creates a grid of of subplots of size (num_rows x num_cols) and returns an axes object for the subplot at subplot_location.

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.plot(x,y)
ax2 = fig.add_subplot(1,2,2)
ax2.plot(x,y)
plt.show(block=False)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.set_xlabel('X') # X Label
ax.set_ylabel('Y') # Y Label
ax.set_title('Simple XY plot') # Tile
ax.scatter(x,y)
plt.show()

# %% [markdown]
# ## Working with DataFrame

# %%
cars = pd.read_csv('../samples/mtcars.csv')
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

mpg.plot()

ax.set_xticks(range(32))

ax.set_xticklabels(cars.iloc[:,0:1].values, rotation=60, fontsize='medium')
ax.set_title('Miles per Gallon of Cars in mtcars')

ax.set_xlabel('car names')
ax.set_ylabel('miles/gal')
# Out:
# Text(0, 0.5, 'miles/gal')

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### Joinplot
# Displays a relationship between 2 variables (bivariate) as well as 1D profiles (univariate) in the margins.

# %%
sns.jointplot( x=cars['cyl'], y=cars['mpg'] )

# %% [markdown]
# ###  Boxplot

# %%
sns.boxplot( x=cars['cyl'], y=cars['mpg'] ) # Min, Max, Mean, Q1, Q3

# %% [markdown]
# ### Pairplots

# %%
sns.pairplot(cars)

# %% [markdown]
# ### Correlation Heatmap

# %%
# Correlation Matrix
cars.corr() # 1 positive corr, 0 no corr, -1 negative corr
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
# Heatmap
sns.heatmap(cars.corr(), annot=True)

# %%
sns.heatmap(abs(cars.corr()), annot=True)
